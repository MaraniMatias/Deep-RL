# %% [markdown]
# <a href="https://colab.research.google.com/github/MaraniMatias/Deep-RL/blob/master/Deep_Reinforcement_Learning_Example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Ruan faw games for Deep Reinforcement Learning
#
# Fuente [Deep-Reinforcement-Learning-Hands-On](https://github.com/PacktPublishing/Deep-Reinforcement-Learning-Hands-On/blob/master/Chapter07/08_dqn_rainbow.py)
#
#
# - **Categorical DQN:** Our network will predict the value probability distribution of actions.
# - **Dueling DQN:** Our network will have two separate paths for value of state distribution and advantage distribution. On the output, both paths will be summed together, providing the final value probability distributions for actions. To force advantage distribution to have a zero mean, we'll subtract distribution with mean advantage in every atom.
# - **NoisyNet:** Our linear layers in the value and advantage paths will be noisy variants of nn.Linear.

# %% [markdown]
# ## Config

# %%
GAME_NAME = "breakout"

# n-step
REWARD_STEPS = 2

# priority replay
PRIO_REPLAY_ALPHA = 0.6
BETA_START = 0.4
BETA_FRAMES = 100000

# C51
Vmax = 10
Vmin = -10
N_ATOMS = 51
DELTA_Z = (Vmax - Vmin) / (N_ATOMS - 1)

# %% [markdown]
# ## Dependecias

# %% [markdown]
# ### Installar

# %%
# !pip install numpy==1.15.4
# !pip install atari-py==0.1.6
# !pip install gym==0.10.9
# !pip install ptan==0.3
# !pip install torch==0.4.1
# !pip install torchvision==0.2.1
# !pip install tensorboard-pytorch==0.7.1
# !pip install tensorflow==1.12.0
# !pip install tensorboard==1.12.0
# Out:
# Requirement already satisfied: numpy==1.15.4 in /usr/local/lib/python3.6/dist-packages (1.15.4)
# Requirement already satisfied: atari-py==0.1.6 in /usr/local/lib/python3.6/dist-packages (0.1.6)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from atari-py==0.1.6) (1.15.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from atari-py==0.1.6) (1.11.0)
# Requirement already satisfied: gym==0.10.9 in /usr/local/lib/python3.6/dist-packages (0.10.9)
# Requirement already satisfied: scipy in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.1.0)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.15.4)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (2.18.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.11.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python3.6/dist-packages (from gym==0.10.9) (1.3.2)
# Requirement already satisfied: urllib3<1.23,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (1.22)
# Requirement already satisfied: idna<2.7,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (2018.11.29)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.0->gym==0.10.9) (3.0.4)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from pyglet>=1.2.0->gym==0.10.9) (0.16.0)
# Requirement already satisfied: ptan==0.3 in /usr/local/lib/python3.6/dist-packages (0.3)
# Requirement already satisfied: torch==0.4.1 in /usr/local/lib/python3.6/dist-packages (0.4.1)
# Requirement already satisfied: torchvision==0.2.1 in /usr/local/lib/python3.6/dist-packages (0.2.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.1) (1.15.4)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.1) (1.11.0)
# Requirement already satisfied: pillow>=4.1.1 in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.1) (5.4.1)
# Requirement already satisfied: torch in /usr/local/lib/python3.6/dist-packages (from torchvision==0.2.1) (0.4.1)
# Requirement already satisfied: tensorboard-pytorch==0.7.1 in /usr/local/lib/python3.6/dist-packages (0.7.1)
# Requirement already satisfied: protobuf in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch==0.7.1) (3.6.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch==0.7.1) (1.11.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from tensorboard-pytorch==0.7.1) (1.15.4)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf->tensorboard-pytorch==0.7.1) (40.6.3)
# Requirement already satisfied: tensorflow==1.12.0 in /usr/local/lib/python3.6/dist-packages (1.12.0)
# Requirement already satisfied: tensorboard<1.13.0,>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.12.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (3.6.1)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.1.0)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.15.0)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.11.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (0.32.3)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (0.7.1)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.0.5)
# Requirement already satisfied: keras-applications>=1.0.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.0.6)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (0.2.0)
# Requirement already satisfied: numpy>=1.13.3 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (1.15.4)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==1.12.0) (0.6.1)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12.0) (0.14.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<1.13.0,>=1.12.0->tensorflow==1.12.0) (3.0.1)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==1.12.0) (40.6.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.6->tensorflow==1.12.0) (2.8.0)
# Requirement already satisfied: tensorboard==1.12.0 in /usr/local/lib/python3.6/dist-packages (1.12.0)
# Requirement already satisfied: grpcio>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (1.15.0)
# Requirement already satisfied: werkzeug>=0.11.10 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (0.14.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (1.11.0)
# Requirement already satisfied: protobuf>=3.4.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (3.6.1)
# Requirement already satisfied: numpy>=1.12.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (1.15.4)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (3.0.1)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /usr/local/lib/python3.6/dist-packages (from tensorboard==1.12.0) (0.32.3)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.4.0->tensorboard==1.12.0) (40.6.3)

# %% [markdown]
# ### Importar

# %%
import sys
import time
import math

import gym
import ptan
import argparse
import numpy as np

import torch
import torch.nn as nn
import torch.nn.functional as F

import torch.optim as optim

from tensorboardX import SummaryWriter

# %% [markdown]
# ### Lib personalizadas
#
# dqn_model

# %%
class NoisyLinear(nn.Linear):
    def __init__(self, in_features, out_features, sigma_init=0.017, bias=True):
        super(NoisyLinear, self).__init__(in_features, out_features, bias=bias)
        self.sigma_weight = nn.Parameter(torch.full((out_features, in_features), sigma_init))
        self.register_buffer("epsilon_weight", torch.zeros(out_features, in_features))
        if bias:
            self.sigma_bias = nn.Parameter(torch.full((out_features,), sigma_init))
            self.register_buffer("epsilon_bias", torch.zeros(out_features))
        self.reset_parameters()

    def reset_parameters(self):
        std = math.sqrt(3 / self.in_features)
        self.weight.data.uniform_(-std, std)
        self.bias.data.uniform_(-std, std)

    def forward(self, input):
        self.epsilon_weight.normal_()
        bias = self.bias
        if bias is not None:
            self.epsilon_bias.normal_()
            bias = bias + self.sigma_bias * self.epsilon_bias.data
        return F.linear(input, self.weight + self.sigma_weight * self.epsilon_weight.data, bias)

# %% [markdown]
# comon

# %%
HYPERPARAMS = {
    'pong': {
        'env_name':         "PongNoFrameskip-v4",
        'stop_reward':      18.0,
        'run_name':         'pong',
        'replay_size':      100000,
        'replay_initial':   10000,
        'target_net_sync':  1000,
        'epsilon_frames':   10**5,
        'epsilon_start':    1.0,
        'epsilon_final':    0.02,
        'learning_rate':    0.0001,
        'gamma':            0.99,
        'batch_size':       32
    },
    'breakout-small': {
        'env_name':         "BreakoutNoFrameskip-v4",
        'stop_reward':      500.0,
        'run_name':         'breakout-small',
        'replay_size':      3*10 ** 5,
        'replay_initial':   20000,
        'target_net_sync':  1000,
        'epsilon_frames':   10 ** 6,
        'epsilon_start':    1.0,
        'epsilon_final':    0.1,
        'learning_rate':    0.0001,
        'gamma':            0.99,
        'batch_size':       64
    },
    'breakout': {
        'env_name':         "BreakoutNoFrameskip-v4",
        'stop_reward':      500.0,
        'run_name':         'breakout',
        'replay_size':      10 ** 6,
        'replay_initial':   50000,
        'target_net_sync':  10000,
        'epsilon_frames':   10 ** 6,
        'epsilon_start':    1.0,
        'epsilon_final':    0.1,
        'learning_rate':    0.00025,
        'gamma':            0.99,
        'batch_size':       32
    },
    'invaders': {
        'env_name': "SpaceInvadersNoFrameskip-v4",
        'stop_reward': 500.0,
        'run_name': 'breakout',
        'replay_size': 10 ** 6,
        'replay_initial': 50000,
        'target_net_sync': 10000,
        'epsilon_frames': 10 ** 6,
        'epsilon_start': 1.0,
        'epsilon_final': 0.1,
        'learning_rate': 0.00025,
        'gamma': 0.99,
        'batch_size': 32
    },
}


def unpack_batch(batch):
    states, actions, rewards, dones, last_states = [], [], [], [], []
    for exp in batch:
        state = np.array(exp.state, copy=False)
        states.append(state)
        actions.append(exp.action)
        rewards.append(exp.reward)
        dones.append(exp.last_state is None)
        if exp.last_state is None:
            last_states.append(state)       # the result will be masked anyway
        else:
            last_states.append(np.array(exp.last_state, copy=False))
    return np.array(states, copy=False), np.array(actions), np.array(rewards, dtype=np.float32), \
           np.array(dones, dtype=np.uint8), np.array(last_states, copy=False)


def calc_loss_dqn(batch, net, tgt_net, gamma, device="cpu"):
    states, actions, rewards, dones, next_states = unpack_batch(batch)

    states_v = torch.tensor(states).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    actions_v = torch.tensor(actions).to(device)
    rewards_v = torch.tensor(rewards).to(device)
    done_mask = torch.ByteTensor(dones).to(device)

    state_action_values = net(states_v).gather(1, actions_v.unsqueeze(-1)).squeeze(-1)
    next_state_values = tgt_net(next_states_v).max(1)[0]
    next_state_values[done_mask] = 0.0

    expected_state_action_values = next_state_values.detach() * gamma + rewards_v
    return nn.MSELoss()(state_action_values, expected_state_action_values)


class RewardTracker:
    def __init__(self, writer, stop_reward):
        self.writer = writer
        self.stop_reward = stop_reward

    def __enter__(self):
        self.ts = time.time()
        self.ts_frame = 0
        self.total_rewards = []
        return self

    def __exit__(self, *args):
        self.writer.close()

    def reward(self, reward, frame, epsilon=None):
        self.total_rewards.append(reward)
        speed = (frame - self.ts_frame) / (time.time() - self.ts)
        self.ts_frame = frame
        self.ts = time.time()
        mean_reward = np.mean(self.total_rewards[-100:])
        epsilon_str = "" if epsilon is None else ", eps %.2f" % epsilon
        print("%d: done %d games, mean reward %.3f, speed %.2f f/s%s" % (
            frame, len(self.total_rewards), mean_reward, speed, epsilon_str
        ))
        sys.stdout.flush()
        if epsilon is not None:
            self.writer.add_scalar("epsilon", epsilon, frame)
        self.writer.add_scalar("speed", speed, frame)
        self.writer.add_scalar("reward_100", mean_reward, frame)
        self.writer.add_scalar("reward", reward, frame)
        if mean_reward > self.stop_reward:
            print("Solved in %d frames!" % frame)
            return True
        return False


class EpsilonTracker:
    def __init__(self, epsilon_greedy_selector, params):
        self.epsilon_greedy_selector = epsilon_greedy_selector
        self.epsilon_start = params['epsilon_start']
        self.epsilon_final = params['epsilon_final']
        self.epsilon_frames = params['epsilon_frames']
        self.frame(0)

    def frame(self, frame):
        self.epsilon_greedy_selector.epsilon = \
            max(self.epsilon_final, self.epsilon_start - frame / self.epsilon_frames)


def distr_projection(next_distr, rewards, dones, Vmin, Vmax, n_atoms, gamma):
    """
    Perform distribution projection aka Catergorical Algorithm from the
    "A Distributional Perspective on RL" paper
    """
    batch_size = len(rewards)
    proj_distr = np.zeros((batch_size, n_atoms), dtype=np.float32)
    delta_z = (Vmax - Vmin) / (n_atoms - 1)
    for atom in range(n_atoms):
        tz_j = np.minimum(Vmax, np.maximum(Vmin, rewards + (Vmin + atom * delta_z) * gamma))
        b_j = (tz_j - Vmin) / delta_z
        l = np.floor(b_j).astype(np.int64)
        u = np.ceil(b_j).astype(np.int64)
        eq_mask = u == l
        proj_distr[eq_mask, l[eq_mask]] += next_distr[eq_mask, atom]
        ne_mask = u != l
        proj_distr[ne_mask, l[ne_mask]] += next_distr[ne_mask, atom] * (u - b_j)[ne_mask]
        proj_distr[ne_mask, u[ne_mask]] += next_distr[ne_mask, atom] * (b_j - l)[ne_mask]
    if dones.any():
        proj_distr[dones] = 0.0
        tz_j = np.minimum(Vmax, np.maximum(Vmin, rewards[dones]))
        b_j = (tz_j - Vmin) / delta_z
        l = np.floor(b_j).astype(np.int64)
        u = np.ceil(b_j).astype(np.int64)
        eq_mask = u == l
        eq_dones = dones.copy()
        eq_dones[dones] = eq_mask
        if eq_dones.any():
            proj_distr[eq_dones, l[eq_mask]] = 1.0
        ne_mask = u != l
        ne_dones = dones.copy()
        ne_dones[dones] = ne_mask
        if ne_dones.any():
            proj_distr[ne_dones, l[ne_mask]] = (u - b_j)[ne_mask]
            proj_distr[ne_dones, u[ne_mask]] = (b_j - l)[ne_mask]
    return proj_distr

# %% [markdown]
# ## Model

# %%
class RainbowDQN(nn.Module):
    def __init__(self, input_shape, n_actions):
        super(RainbowDQN, self).__init__()

        self.conv = nn.Sequential(
            nn.Conv2d(input_shape[0], 32, kernel_size=8, stride=4),
            nn.ReLU(),
            nn.Conv2d(32, 64, kernel_size=4, stride=2),
            nn.ReLU(),
            nn.Conv2d(64, 64, kernel_size=3, stride=1),
            nn.ReLU()
        )

        conv_out_size = self._get_conv_out(input_shape)
        self.fc_val = nn.Sequential(
            NoisyLinear(conv_out_size, 512),
            nn.ReLU(),
            NoisyLinear(512, N_ATOMS)
        )

        self.fc_adv = nn.Sequential(
            NoisyLinear(conv_out_size, 512),
            nn.ReLU(),
            NoisyLinear(512, n_actions * N_ATOMS)
        )

        self.register_buffer("supports", torch.arange(Vmin, Vmax+DELTA_Z, DELTA_Z))
        self.softmax = nn.Softmax(dim=1)

    def _get_conv_out(self, shape):
        o = self.conv(torch.zeros(1, *shape))
        return int(np.prod(o.size()))

    def forward(self, x):
        batch_size = x.size()[0]
        fx = x.float() / 256
        conv_out = self.conv(fx).view(batch_size, -1)
        val_out = self.fc_val(conv_out).view(batch_size, 1, N_ATOMS)
        adv_out = self.fc_adv(conv_out).view(batch_size, -1, N_ATOMS)
        adv_mean = adv_out.mean(dim=1, keepdim=True)
        return val_out + adv_out - adv_mean

    def both(self, x):
        cat_out = self(x)
        probs = self.apply_softmax(cat_out)
        weights = probs * self.supports
        res = weights.sum(dim=2)
        return cat_out, res

    def qvals(self, x):
        return self.both(x)[1]

    def apply_softmax(self, t):
        return self.softmax(t.view(-1, N_ATOMS)).view(t.size())


def calc_loss(batch, batch_weights, net, tgt_net, gamma, device="cpu"):
    states, actions, rewards, dones, next_states = unpack_batch(batch)
    batch_size = len(batch)

    states_v = torch.tensor(states).to(device)
    actions_v = torch.tensor(actions).to(device)
    next_states_v = torch.tensor(next_states).to(device)
    batch_weights_v = torch.tensor(batch_weights).to(device)

    # next state distribution
    # dueling arch -- actions from main net, distr from tgt_net

    # calc at once both next and cur states
    distr_v, qvals_v = net.both(torch.cat((states_v, next_states_v)))
    next_qvals_v = qvals_v[batch_size:]
    distr_v = distr_v[:batch_size]

    next_actions_v = next_qvals_v.max(1)[1]
    next_distr_v = tgt_net(next_states_v)
    next_best_distr_v = next_distr_v[range(batch_size), next_actions_v.data]
    next_best_distr_v = tgt_net.apply_softmax(next_best_distr_v)
    next_best_distr = next_best_distr_v.data.cpu().numpy()

    dones = dones.astype(np.bool)

    # project our distribution using Bellman update
    proj_distr = distr_projection(next_best_distr, rewards, dones, Vmin, Vmax, N_ATOMS, gamma)

    # calculate net output
    state_action_values = distr_v[range(batch_size), actions_v.data]
    state_log_sm_v = F.log_softmax(state_action_values, dim=1)
    proj_distr_v = torch.tensor(proj_distr).to(device)

    loss_v = -state_log_sm_v * proj_distr_v
    loss_v = batch_weights_v * loss_v.sum(dim=1)
    return loss_v.mean(), loss_v + 1e-5

# %% [markdown]
# # Main

# %%
if __name__ == "__main__":
    params = HYPERPARAMS[GAME_NAME]
    params['epsilon_frames'] *= 2
    device = torch.device("cuda")

    env = gym.make(params['env_name'])
    env = ptan.common.wrappers.wrap_dqn(env)

    writer = SummaryWriter(comment="-" + params['run_name'] + "-rainbow")
    net = RainbowDQN(env.observation_space.shape, env.action_space.n).to(device)
    tgt_net = ptan.agent.TargetNet(net)
    agent = ptan.agent.DQNAgent(lambda x: net.qvals(x), ptan.actions.ArgmaxActionSelector(), device=device)

    exp_source = ptan.experience.ExperienceSourceFirstLast(env, agent, gamma=params['gamma'], steps_count=REWARD_STEPS)
    buffer = ptan.experience.PrioritizedReplayBuffer(exp_source, params['replay_size'], PRIO_REPLAY_ALPHA)
    optimizer = optim.Adam(net.parameters(), lr=params['learning_rate'])

    frame_idx = 0
    beta = BETA_START

    with RewardTracker(writer, params['stop_reward']) as reward_tracker:
        while True:
            frame_idx += 1
            buffer.populate(1)
            beta = min(1.0, BETA_START + frame_idx * (1.0 - BETA_START) / BETA_FRAMES)

            new_rewards = exp_source.pop_total_rewards()
            if new_rewards:
                if reward_tracker.reward(new_rewards[0], frame_idx):
                    break

            if len(buffer) < params['replay_initial']:
                continue

            optimizer.zero_grad()
            batch, batch_indices, batch_weights = buffer.sample(params['batch_size'], beta)
            loss_v, sample_prios_v = calc_loss(batch, batch_weights, net, tgt_net.target_model,
                                               params['gamma'] ** REWARD_STEPS, device=device)
            loss_v.backward()
            optimizer.step()
            buffer.update_priorities(batch_indices, sample_prios_v.data.cpu().numpy())

            if frame_idx % params['target_net_sync'] == 0:
              tgt_net.sync()
# Out:
# /usr/local/lib/python3.6/dist-packages/gym/envs/registration.py:14: PkgResourcesDeprecationWarning: Parameters to load are deprecated.  Call .resolve and .require separately.
#   result = entry_point.load(False)
# 53: done 1 games, mean reward 1.000, speed 154.51 f/s
# 77: done 2 games, mean reward 0.500, speed 161.35 f/s
# 101: done 3 games, mean reward 0.333, speed 167.18 f/s
# 125: done 4 games, mean reward 0.250, speed 153.78 f/s
# 149: done 5 games, mean reward 0.200, speed 154.78 f/s
# 173: done 6 games, mean reward 0.167, speed 166.41 f/s
# 225: done 7 games, mean reward 0.286, speed 151.95 f/s
# 249: done 8 games, mean reward 0.250, speed 165.54 f/s
# 273: done 9 games, mean reward 0.222, speed 162.45 f/s
# 297: done 10 games, mean reward 0.200, speed 146.75 f/s
# 321: done 11 games, mean reward 0.182, speed 159.95 f/s
# 345: done 12 games, mean reward 0.167, speed 165.78 f/s
# 369: done 13 games, mean reward 0.154, speed 159.96 f/s
# 393: done 14 games, mean reward 0.143, speed 158.10 f/s
# 417: done 15 games, mean reward 0.133, speed 152.42 f/s
# 441: done 16 games, mean reward 0.125, speed 157.11 f/s
# 465: done 17 games, mean reward 0.118, speed 157.61 f/s
# 489: done 18 games, mean reward 0.111, speed 155.43 f/s
# 513: done 19 games, mean reward 0.105, speed 162.83 f/s
# 537: done 20 games, mean reward 0.100, speed 150.88 f/s
# 561: done 21 games, mean reward 0.095, speed 161.12 f/s
# 585: done 22 games, mean reward 0.091, speed 159.46 f/s
# 609: done 23 games, mean reward 0.087, speed 148.21 f/s
# 633: done 24 games, mean reward 0.083, speed 164.13 f/s
# 657: done 25 games, mean reward 0.080, speed 152.76 f/s
# 681: done 26 games, mean reward 0.077, speed 161.20 f/s
# 705: done 27 games, mean reward 0.074, speed 169.02 f/s
# 729: done 28 games, mean reward 0.071, speed 154.53 f/s
# 753: done 29 games, mean reward 0.069, speed 162.95 f/s
# 777: done 30 games, mean reward 0.067, speed 148.63 f/s
# 801: done 31 games, mean reward 0.065, speed 164.67 f/s
# 853: done 32 games, mean reward 0.094, speed 167.54 f/s
# 877: done 33 games, mean reward 0.091, speed 165.30 f/s
# 901: done 34 games, mean reward 0.088, speed 160.68 f/s
# 925: done 35 games, mean reward 0.086, speed 152.40 f/s
# 949: done 36 games, mean reward 0.083, speed 157.32 f/s
# 973: done 37 games, mean reward 0.081, speed 163.40 f/s
# 997: done 38 games, mean reward 0.079, speed 164.74 f/s
# 1021: done 39 games, mean reward 0.077, speed 165.38 f/s
# 1045: done 40 games, mean reward 0.075, speed 147.48 f/s
# 76136: done 2410 games, mean reward 0.320, speed 24.19 f/s
# 76160: done 2411 games, mean reward 0.320, speed 24.16 f/s
# 76184: done 2412 games, mean reward 0.320, speed 23.84 f/s
# 76208: done 2413 games, mean reward 0.320, speed 23.90 f/s
# 76232: done 2414 games, mean reward 0.320, speed 23.20 f/s
# 76256: done 2415 games, mean reward 0.300, speed 23.43 f/s
# 76280: done 2416 games, mean reward 0.300, speed 24.02 f/s
# 76304: done 2417 games, mean reward 0.300, speed 23.92 f/s
# 76403: done 2418 games, mean reward 0.300, speed 24.02 f/s
# 76427: done 2419 games, mean reward 0.300, speed 23.92 f/s
# 76451: done 2420 games, mean reward 0.300, speed 23.60 f/s
# 76475: done 2421 games, mean reward 0.300, speed 23.85 f/s
# 76499: done 2422 games, mean reward 0.300, speed 23.94 f/s
# 76523: done 2423 games, mean reward 0.300, speed 24.05 f/s
# 76622: done 2424 games, mean reward 0.320, speed 24.05 f/s
# 76646: done 2425 games, mean reward 0.320, speed 23.44 f/s
# 76670: done 2426 games, mean reward 0.320, speed 23.91 f/s
# 76694: done 2427 games, mean reward 0.320, speed 23.92 f/s
# 76718: done 2428 games, mean reward 0.300, speed 24.02 f/s
# 76742: done 2429 games, mean reward 0.300, speed 23.82 f/s
# 76766: done 2430 games, mean reward 0.300, speed 23.66 f/s
# 76790: done 2431 games, mean reward 0.300, speed 23.82 f/s
# 76814: done 2432 games, mean reward 0.300, speed 23.76 f/s
# 76838: done 2433 games, mean reward 0.300, speed 23.77 f/s
# 76862: done 2434 games, mean reward 0.300, speed 23.93 f/s
# 76886: done 2435 games, mean reward 0.300, speed 23.54 f/s
# 76910: done 2436 games, mean reward 0.300, speed 24.13 f/s
# 77009: done 2437 games, mean reward 0.320, speed 24.07 f/s
# 77033: done 2438 games, mean reward 0.320, speed 24.04 f/s
# 77057: done 2439 games, mean reward 0.320, speed 24.06 f/s
# 77081: done 2440 games, mean reward 0.320, speed 23.53 f/s
# 77105: done 2441 games, mean reward 0.320, speed 23.98 f/s
# 77129: done 2442 games, mean reward 0.320, speed 23.94 f/s
# 77153: done 2443 games, mean reward 0.320, speed 23.91 f/s
# 77177: done 2444 games, mean reward 0.320, speed 23.97 f/s
# 77201: done 2445 games, mean reward 0.300, speed 23.79 f/s
# 77225: done 2446 games, mean reward 0.300, speed 23.44 f/s
# 77249: done 2447 games, mean reward 0.280, speed 23.35 f/s
# 77273: done 2448 games, mean reward 0.270, speed 23.22 f/s
# 77372: done 2449 games, mean reward 0.290, speed 23.73 f/s
# 77396: done 2450 games, mean reward 0.290, speed 24.17 f/s
# 77420: done 2451 games, mean reward 0.290, speed 24.01 f/s
# 77444: done 2452 games, mean reward 0.290, speed 24.15 f/s
# 77468: done 2453 games, mean reward 0.270, speed 23.84 f/s
# 77492: done 2454 games, mean reward 0.270, speed 23.98 f/s
# 77516: done 2455 games, mean reward 0.270, speed 23.72 f/s
# 77540: done 2456 games, mean reward 0.270, speed 24.19 f/s
# 77564: done 2457 games, mean reward 0.250, speed 24.16 f/s
# 77588: done 2458 games, mean reward 0.250, speed 24.20 f/s
# 82556: done 2605 games, mean reward 0.260, speed 24.00 f/s
# 82580: done 2606 games, mean reward 0.260, speed 24.17 f/s
# 82604: done 2607 games, mean reward 0.240, speed 24.06 f/s
# 82628: done 2608 games, mean reward 0.240, speed 24.18 f/s
# 82652: done 2609 games, mean reward 0.240, speed 24.15 f/s
# 82751: done 2610 games, mean reward 0.260, speed 24.33 f/s
# 82775: done 2611 games, mean reward 0.260, speed 24.14 f/s
# 82799: done 2612 games, mean reward 0.260, speed 24.18 f/s
# 82823: done 2613 games, mean reward 0.260, speed 24.21 f/s
# 82847: done 2614 games, mean reward 0.260, speed 24.16 f/s
# 82871: done 2615 games, mean reward 0.260, speed 23.85 f/s
# 82895: done 2616 games, mean reward 0.260, speed 23.80 f/s
# 82919: done 2617 games, mean reward 0.260, speed 24.06 f/s
# 83018: done 2618 games, mean reward 0.280, speed 24.52 f/s
# 83090: done 2619 games, mean reward 0.270, speed 24.47 f/s
# 83114: done 2620 games, mean reward 0.260, speed 23.99 f/s
# 83138: done 2621 games, mean reward 0.260, speed 24.02 f/s
# 83237: done 2622 games, mean reward 0.280, speed 24.40 f/s
# 83261: done 2623 games, mean reward 0.280, speed 24.38 f/s
# 83285: done 2624 games, mean reward 0.280, speed 24.25 f/s
# 83357: done 2625 games, mean reward 0.290, speed 24.35 f/s
# 83381: done 2626 games, mean reward 0.290, speed 24.46 f/s
# 83480: done 2627 games, mean reward 0.290, speed 24.12 f/s
# 83504: done 2628 games, mean reward 0.280, speed 23.41 f/s
# 83528: done 2629 games, mean reward 0.280, speed 23.68 f/s
# 83552: done 2630 games, mean reward 0.280, speed 23.35 f/s
# 83576: done 2631 games, mean reward 0.280, speed 23.50 f/s
# 83600: done 2632 games, mean reward 0.280, speed 23.63 f/s
# 83624: done 2633 games, mean reward 0.280, speed 23.39 f/s
# 83648: done 2634 games, mean reward 0.280, speed 23.27 f/s
# 83672: done 2635 games, mean reward 0.280, speed 23.25 f/s
# 83696: done 2636 games, mean reward 0.280, speed 23.62 f/s
# 83720: done 2637 games, mean reward 0.280, speed 23.63 f/s
# 83744: done 2638 games, mean reward 0.280, speed 23.89 f/s
# 83768: done 2639 games, mean reward 0.280, speed 24.15 f/s
# 83867: done 2640 games, mean reward 0.300, speed 24.30 f/s
# 83891: done 2641 games, mean reward 0.300, speed 24.20 f/s
# 83990: done 2642 games, mean reward 0.320, speed 24.26 f/s
# 84062: done 2643 games, mean reward 0.330, speed 24.33 f/s
# 84135: done 2644 games, mean reward 0.340, speed 24.30 f/s
# 84159: done 2645 games, mean reward 0.340, speed 23.92 f/s
# 84183: done 2646 games, mean reward 0.340, speed 24.20 f/s
# 84207: done 2647 games, mean reward 0.340, speed 24.13 f/s
# 84306: done 2648 games, mean reward 0.360, speed 24.44 f/s
# 84330: done 2649 games, mean reward 0.360, speed 23.93 f/s
# 84354: done 2650 games, mean reward 0.360, speed 23.68 f/s
# 84378: done 2651 games, mean reward 0.360, speed 24.23 f/s
# 84477: done 2652 games, mean reward 0.380, speed 24.43 f/s
# 84501: done 2653 games, mean reward 0.380, speed 24.34 f/s
